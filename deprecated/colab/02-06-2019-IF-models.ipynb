# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
u = [-60]

u_rest = -40

duration = 150 #1000 ms

delta_t = 0.1

tao = 20

t = [0]

def linear_F_u(u_last, I_t, u_rest, tao, params):
  return 1/tao * (-u_last + u_rest + params["R"]*I)

def fixed_current(u):
  return lambda t: u

R = 1

theta = -35

    
def neuron(u_rest, theta, tao, duration, delta_t, F_u, I_t, params):
  u = [u_rest]
  t = [0]
  s = []

  for t_step in np.arange(delta_t, duration, step = delta_t):
    t.append(t_step)
    if u[-1] > theta
      u.append(u_rest)
      s.append(True)
    else:
      delta_u = delta_t*(F_u(u[-1], u_rest, tao, params) + R*I_t(t_step)
      u.append(u[-1] + delta_u)
      s.append(False)

  return t, u, s

  
  
plt.ylim([-70, 0])
plt.plot(t, u)
